# %% [markdown]
# # Histogram

# %%
# import matplotlib.pyplot as plt
import pandas as pd

#import data
dataset = pd.read_csv ("data.csv")  

dataset

# %%
plt.hist(dataset["Temperature"])
# Out:
# (array([ 4., 10., 12., 10., 13., 20., 15., 19., 28., 12.]),
#  array([35.4  , 41.025, 46.65 , 52.275, 57.9  , 63.525, 69.15 , 74.775,
#         80.4  , 86.025, 91.65 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #  Line Chart

# %%
dataset.plot()
# Out:
# <AxesSubplot:>

# %%
Line_data = pd.DataFrame(dataset, columns = ['dept_1 sales', 'dept_2 sales', 'dept_3 sales'])
Line_data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Area Chart

# %%
Line_data.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar Chart

# %%
Line1_data = pd.DataFrame(dataset, columns = ['Fuel_Price'])
                                  
Line1_data[0:143:10].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plot

# %%
dataset.plot.scatter(x = 'Unemployment', y = 'Fuel_Price')
# Out:
# <AxesSubplot:xlabel='Unemployment', ylabel='Fuel_Price'>
